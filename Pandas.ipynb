# %% [markdown]
# <a href="https://colab.research.google.com/github/SrijaG29/libraries-practice/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas**
#
# -> It is a library in the python ecosystem, particularly for **data manipulation** andd **analysis** and it is widely used in **ML.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# There are 2 core objects in pandas:
#
#
#
# 1.   Data Frame.
# 2.   Series.

# %% [markdown]
# **Data Frames**
#
# -> It is a table. It contains an array of individual entries. Each of which has a certain values.
#
# -> Each entry corresponds to a row/record and a column.

# %%
# pd.DataFrame({'Yes':[7,7],'No':[4,4]})
# pd.DataFrame({'Fruits':['Apple','Mango','Orange'],'Colour':['Red','Yellow','Orange']})

#  in this we can also add index values like default it will come 0,1..

df = pd.DataFrame({'Fruits':['Apple','Mango','Orange','Strawberry'],'Colour':['Red','Yellow',np.nan,'Red']},
             index=['Prod1','Prod2','Prod3','Prod4'])
df
# Out:
#            Fruits  Colour
# Prod1       Apple     Red
# Prod2       Mango  Yellow
# Prod3      Orange     NaN
# Prod4  Strawberry     Red

# %% [markdown]
# **Series**
#
# -> It is a **sequence of data values.**
#
# -> DataFrame is a **table**, Series is a **list**

# %%
# pd.Series([1,2,3,4])

# indexing
# pd.Series([1,2,3,4],index=['a','b','c','d'])

# name to the list
sf = pd.Series([1,2,3,4],index=['a','b','c','d'],name='Numbers')

# %%
# df.loc[df.Colour.isnull()]
# df.loc[df.Colour.notnull()]
# df.isna().sum()
# df.drop_duplicates(subset = "Colour")
# df.dropna(subset = "Colour")
# df.replace(np.nan,'Blue')
# df["Colour"] = "Blue"
# df.loc["Prod2","Colour"] = "Pink"
# Out:
# Prod1       Red colour
# Prod2    Yellow colour
# Prod3             None
# Prod4       Red colour
# Name: Colour, dtype: object

# %%
# Map: It will take only one column
def addextra(x):
   if not pd.isna(x):
    return str(x) + ' colour'
y = df.Colour.map(addextra)
y
# Out:
# Prod1       Red colour
# Prod2    Yellow colour
# Prod3             None
# Prod4       Red colour
# Name: Colour, dtype: object

# %%
# Apply: Transform a wholedataframe by calling a custom method on each row
# def manipulate(x):
#    print(x)
#    return x
# y = df.apply(manipulate,axis="columns")
# y

# def manipulate(x):
#    print(x)
#    return x
# y = df.apply(manipulate,axis="rows")
# y

# def manipulate(x):
#   print(x)
#   return x
# y = df.applymap(manipulate)
# y
# Out:
# Apple
# Mango
# Orange
# Strawberry
# Red
# Yellow
# nan
# Red
#            Fruits  Colour
# Prod1       Apple     Red
# Prod2       Mango  Yellow
# Prod3      Orange     NaN
# Prod4  Strawberry     Red

# %%
#grouping
# df.groupby("Colour").Fruits.count()
# y = df.groupby("Colour").Fruits.agg([len,min,max])
y
# x = y.reset_index()
# x
# x.set_index("Colour")
# y.sort_index(ascending=True)
# y.sort_index(ascending=False)

# y.sort_values(by = "len",ascending=True)
# y.sort_values(by = "len",ascending=False)
# y["min"].dtype
# y.len.dtype
f = y.rename(columns = {"min":"Minimum","max":"Maximum"})
# f
# f.Minimum.dtype
# f.Minimum = f.Minimum.astype('str')
# f.Minimum.dtype
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-c89563319243> in <cell line: 18>()
#      16 # f
#      17 # f.Minimum.dtype
# ---> 18 f.Minimum = f.Minimum.astype('int64')
#      19 f.Minimum.dtype
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6322         else:
#    6323             # else, only a single dtype is given
# -> 6324             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325             return self._constructor(new_data).__finalize__(self, method="astype")
#    6326
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     449             copy = False
#     450
# --> 451         return self.apply(
#     452             "astype",
#     453             dtype=dtype,
#
# ...
