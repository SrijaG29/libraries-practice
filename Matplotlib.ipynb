# %% [markdown]
# <a href="https://colab.research.google.com/github/SrijaG29/libraries-practice/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Matplotlib**
#
# -> Matplotlib is a powerful plotting library in Python used for creating static, animated, and interactive visualizations.
#
# -> Matplotlib’s primary purpose is to provide users with the tools and functionality to represent data graphically, making it easier to analyze and understand.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# **Basic Graph**

# %%
# line 1
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Keyword Argument Notation
plt.plot(x,y, label = '2x',color='blue',linewidth=1,linestyle='--',marker='*',
         markersize=7,markeredgecolor='red')

# line 2
# x2 = [0,1,2,3,4]
y2 = [i**2 for i in x]

# plt.plot(x2,y2,'r*-',label='x^2')

# Plot part of the graph as line
plt.plot(x[:3],y2[:3], 'r*-',label = 'x^2')
# Plot remainder of graph as a dot
plt.plot(x[2:],y2[2:], 'r*--')

# Add a title (specify font parameters with fontdict)
plt.title('My First Graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8])

# Add annotations for specific points
plt.annotate('(1,2)',xy=(1, 2), xytext=(1, 3))
plt.annotate('(2,5)', xy=(2, 4), xytext=(2, 5))
plt.annotate('(3,6)', xy=(3, 6), xytext=(3, 7))

# plt.fill_between(x,y,y2,color='green',aplha=0.5)
# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.

# %% [markdown]
# Stem graph

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

plt.stem(x,y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a line chart
plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o', linestyle='-')

# Add annotations
for i, (xi, yi) in enumerate(zip(x, y)):
    plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 10), ha='center')

# Add title and labels
plt.title('Line Chart with Annotations')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Display grid
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import random as random

plt.figure(figsize=(8, 6))
students = ["Jane","Joe","Beck","Tom",
            "Sam","Eva"]

marks=[]
for i in range(0,len(students)):
     marks.append(random.randint(0, 101))


plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("CLASS RECORDS")
plt.plot(students,marks,'b--',marker='*')
plt.show()

# %% [markdown]
# **Bar Chart**

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values,color='maroon',width=0.7)
patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
    # bar.set_hatch(patterns.pop())

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))

# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]

# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# print(br1)
# print(br2)
# print(br3)


# Make the plot
patterns= ['/', 'O', '*','.','|']
x = plt.bar(br1,IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='IT')

for bar in x:
    bar.set_hatch(patterns.pop(0))

patterns= ['/', 'O', '*','.','|']

y = plt.bar(br2,ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')

for bar in y:
    bar.set_hatch(patterns.pop(0))

patterns= ['/', 'O', '*','.','|']

z = plt.bar(br3,CSE, color ='b', width = barWidth,
        edgecolor ='grey', label ='CSE')

for bar in z:
    bar.set_hatch(patterns.pop(0))

# Adding labels and title
plt.xlabel('Branch', fontweight ='bold', fontsize = 10)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 10)
plt.title('Comparison of IT, ECE, and CSE')

#adding xticks
plt.xticks([r + barWidth for r in range(len(IT))],[2015,2016,2017,2018,2019])

plt.legend()
plt.show()

# %% [markdown]
# **Scatter plot**

# %%
x_data = np.random.random(50)*100
y_data = np.random.random(50)*100


plt.scatter(x_data,y_data,c='blue',marker = '.',s=150)
plt.show()

# %%
x_data = np.random.random(1000)*100
y_data = np.random.random(1000)*100


plt.scatter(x_data,y_data,c='blue',marker = '*',s=150,alpha=0.3)
plt.show()

# %%
#Horizontal bar graph
y=['one', 'two', 'three', 'four', 'five']

# getting values against each value of y
x=[5,24,35,67,12]
plt.barh(y, x)

# setting label of y-axis
plt.ylabel("pen sold")

# setting label of x-axis
plt.xlabel("Quantity")
plt.title("Horizontal bar graph")
plt.show()

# %%
#stacked bar graph
# create data
x = ['A', 'B', 'C', 'D']
y1 = [10, 20, 10, 30]
y2 = [20, 25, 15, 25]

# plot bars in stack manner
plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.show()

# %%
d = {'Fruits':['Apple','Mango','Banana','Orange'],
     'Colour':['Red','Yellow','Yellow','Orange']}
bins=[0,1,2,3]
df = pd.DataFrame(d,index=['Prod1','Prod2','Prod3','Prod4'])
plt.hist(df['Colour'],bins=bins,color='red')
# ,edgecolor='black',linewidth=1
plt.title('Fruits and it\'s Colour')
plt.xlabel('Colour')
plt.ylabel('Count')
plt.xticks(bins)
plt.show()

# %%
ages = np.random.normal(20,1.5,1000)


plt.hist(ages,edgecolor='black')
# Out:
# (array([ 12.,  31., 111., 219., 256., 205., 121.,  41.,   3.,   1.]),
#  array([15.46569581, 16.47070607, 17.47571633, 18.48072658, 19.48573684,
#         20.49074709, 21.49575735, 22.5007676 , 23.50577786, 24.51078811,
#         25.51579837]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages,edgecolor='black',cumulative=True)
# Out:
# (array([  12.,   43.,  154.,  373.,  629.,  834.,  955.,  996.,  999.,
#         1000.]),
#  array([15.46569581, 16.47070607, 17.47571633, 18.48072658, 19.48573684,
#         20.49074709, 21.49575735, 22.5007676 , 23.50577786, 24.51078811,
#         25.51579837]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Pie Chart**

# %%
lang = ['c++','c#','python','java','go']
votes = [10,30,20,40,10]
plt.pie(votes,labels = lang)
plt.show()

# %%
explodes = [0.2,0,0,0.2,0]


plt.pie(votes,labels = lang,explode=explodes)
plt.show()

# %%
plt.pie(votes,labels = lang,explode=explodes,autopct = '%.2f%%',pctdistance=0.8)
plt.show()

# %% [markdown]
# **Box Plot**

# %%
heights = np.random.normal(172,8,300)


plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78e287038c70>,
#   <matplotlib.lines.Line2D at 0x78e2870391e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x78e28703bb20>,
#   <matplotlib.lines.Line2D at 0x78e287039a80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x78e28703ae00>],
#  'medians': [<matplotlib.lines.Line2D at 0x78e28703ac20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78e287039660>],
#  'means': []}

# %%
first = np.linspace(0,10,25)
second = np.linspace(10,200,25)
third = np.linspace(200,210,25)
fourth = np.linspace(210,230,25)
data = np.concatenate((first,second,third,fourth))

plt.boxplot(data)
plt.show()

# %% [markdown]
# **Plot customization**

# %%
years = [2014+x for x in range(8)]
income = [55,56,62,61,72,72,73,75]
income_ticks = list(range(50,81,2))
plt.plot(years,income)
#title
plt.title('income of jhon (in usd)',fontsize = 30)
#xlabel
plt.xlabel('years')
#ylabel
plt.ylabel('yearly income(in usd)')
#to make y_axis into 55.0K usd instead of just showing 55.0
# plt.yticks(income_ticks,[f"{x}k usd" for x in income_ticks])
plt.yticks(income_ticks,[f"{x}k usd" for x in income_ticks])
#Similary we can do for x axis
plt.xticks(years,[f"{x}yy" for x in years],rotation = 45)
plt.show()

# %% [markdown]
# **Plot background**

# %%
from matplotlib import style
style.use("dark_background")
# style.use("white_background")

# %% [markdown]
# **Multiple figures**

# %%
x = np.arange(100)
fig,axs = plt.subplots(2,2)
axs[0,0].plot(x,np.sin(x))
axs[0,0].set_title('sine wave')

axs[0,1].plot(x,np.cos(x))
axs[0,1].set_title('cosine wave')

axs[1,0].plot(x,np.tan(x))
axs[1,0].set_title('tan wave')

axs[1,1].plot(x,np.log(x))
axs[1,1].set_title('log wave')
axs[1,1].set_xlabel('x')
axs[1,1].set_ylabel('y')
plt.tight_layout()
fig.suptitle('wave plots')
plt.show()
# Out:
# <ipython-input-28-c78730a36e2f>:12: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x,np.log(x))

# %% [markdown]
# **3D ploting**

# %%
ax = plt.axes(projection = '3d')
x = np.arange(0,50,1.1)
y = np.sin(x)
z = np.cos(x)
# ax.bar(x,y,z)
ax.stem(x,y,z)
plt.show()

# %%
import random

head_tails = [0,0]
for _ in range(10):
  temp = random.randint(0,1)
  head_tails[temp] += 1
  plt.bar(['head','tails'],head_tails,color=['r','b'])
  plt.pause(0.0001)
plt.show()
